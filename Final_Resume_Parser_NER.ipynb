# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratyushk2003/Resume-Screening-NLP/blob/main/Final_Resume_Parser_NER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Extracting skills from resume**

# %%
import spacy

# %%
# !python -m spacy download en_core_web_sm
# !python -m spacy download en_core_web_lg
# Out:
# 2023-10-31 12:48:14.955835: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-31 12:48:14.955916: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-31 12:48:14.955961: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-31 12:48:17.026580: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Collecting en-core-web-lg==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.6.0/en_core_web_lg-3.6.0-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 790.3 kB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-lg==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.1.3)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.6.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# %%
train = [
         ("Skilled with Wrike and AtTask project management software. ",{"entities":[(13,18,"hard_skills"),(23,29,"hard_skills")]}),
         ("Expert knowledge of SQL and relational database management systems. ",{"entities":[(20,23,"hard_skills"),(28,66,"hard_skills")]}),
         ("Proficient in Microsoft Office (Word, Excel, Outlook, PowerPoint, Visio). ",{"entities":[(14,30,"hard_skills"),(32,36,"hard_skills"),(38,43,"hard_skills"),(45,52,"hard_skills"),(54,64,"hard_skills"),(66,71,"hard_skills")]}),
         ("Provided technical leadership and training to ensure on time and in budget project delivery ",{"entities":[(19,29,"soft_skills")]}),
         ("Experienced at managing relational and non-relational database software such as MySQL, SQLite3, Mongo DB, and JSON ",{"entities":[(80,85,"hard_skills"),(87,94,"hard_skills"),(96,104,"hard_skills"),(110,114,"hard_skills")]}),
         ("Proficient in PHP, Ruby on Rails, Java, C++, and Python ",{"entities":[(14,17,"hard_skills"),(19,32,"hard_skills"),(34,38,"hard_skills"),(40,43,"hard_skills"),(49,55,"hard_skills")]}),
         ("Used predictive analytics such as machine learning and data mining techniques to forecast company sales of new products with a 95% accuracy rate ",{"entities":[(5,25,"hard_skills"),(34,50,"hard_skills"),(55,66,"hard_skills"),(81,89,"hard_skills")]}),
         ("Improved data mining processes, resulting in a 20% decrease in time needed to infer insights from customer data used to develop marketing strategies ",{"entities":[(9,20,"hard_skills")]}),
         ("Used advanced Microsoft Excel to create pivot tables, used VLOOKUP, and other Excel functions",{"entities":[(14,29,"hard_skills"),(40,52,"hard_skills"),(59,66,"hard_skills"),(78,93,"hard_skills")]}),
         ("Data Scientist with 4+ years of experience executing data-driven solutions to increase efficiency, accuracy, and utility of internal data processing. ",{"entities":[(0,14,"hard_skills")]}),
         ("Experienced at creating data regression models, using predictive data modeling, and analyzing data mining algorithms to deliver insights and implement action-oriented solutions to complex business problems. ",{"entities":[(29,39,"hard_skills"),(54,78,"hard_skills"),(84,93,"soft_skills"),(94,105,"hard_skills")]}),
         ("Increased accessibility and usability of customer data by redesigning data visualization techniques to include statistical graphs and information graphics ",{"entities":[(70,88,"hard_skills")]}),
         ("Utilized web scraping techniques to extract and organize competitor data ",{"entities":[(9,21,"hard_skills")]}),
         ("Conducted a data regression analysis of the relationship between company stock prices and industry trends, achieving a 15% more accurate prediction of performance than previous years ",{"entities":[(17,27,"hard_skills")]}),
         ("Used statistical techniques for hypothesis testing to validate data and interpretations",{"entities":[(32,50,"hard_skills")]}),
         ("Designed and built statistical analysis models on large data sets (e.g., Aster, Teradata) that helped increase online sales (up to 15% per product) and lowered cart-abandonment rate by 23%.",{"entities":[(19,39,"hard_skills"),(73,78,"hard_skills"),(80,88,"hard_skills")]}),
         ("Created visually impactful dashboards in Excel and Tableau for data reporting by using pivot tables and VLOOKUP. Extracted, interpreted and analyzed data to identify key metrics and transform raw data into meaningful, actionable information.",{"entities":[(41,47,"hard_skills"),(51,58,"hard_skills"),(104,111,"hard_skills")]}),
         ("Conduct data mining, data modeling, statistical analysis, business intelligence gathering, trending and benchmarking. Data analytics supports decisions for high-priority, enterprise initiatives involving IT/product development, customer service improvement, organizational realignment and process reengineering.",{"entities":[(8,19,"hard_skills"),(20,34,"hard_skills"),(36,56,"hard_skills"),(58,79,"hard_skills"),(118,132,"hard_skills")]}),
         ("Research and develop state of the art techniques in the field of computer vision, ML and DL ",{"entities":[(65,80,"hard_skills"),(82,84,"hard_skills"),(89,91,"hard_skills")]}),
         ("Research and develop deep learning algorithms ",{"entities":[(21,34,"hard_skills"),(35,45,"hard_skills")]}),
         ("Research & develop Machine Learning models for security problems, in the areas of Networking, Application & Data ",{"entities":[(19,35,"hard_skills")]}),
         ("Develop new machine learning models to detect malicious activity on mobile devices",{"entities":[(12,28,"hard_skills")]}),
         ("Design, conduct, and report results from prototype or proof-of-concept research projects that focus on 1) new tools, methods, or algorithms, 2) new scientific domains or application areas, or 3) new data sets or sources ",{"entities":[]}),
         ("Work with every investment team in MBFI (Credit, Macro, Equities, RV, Securitized, Mid-horizon etc.) to introduce cutting-edge techniques and innovative data sources across the Fund ",{"entities":[]}),
         ("Create innovative, systematic investment signals and strategies based on a rigorous, peer-reviewed research process ",{"entities":[(0,0,"soft_skills")]}),
         ("Develop the teams capabilities in data science and machine-learning, and apply them to create new data-driven insights ",{"entities":[(34,46,"hard_skills"),(51,67,"hard_skills"),(98,109,"soft_skills")]}),
         ("This role will suit you if you thrive on working in a fast paced environment where your work has high impact ",{"entities":[(54,64,"soft_skills")]}),
         ("Work closely with development teams to ensure accurate integration of machine learning models into firm platforms ",{"entities":[(70,86,"hard_skills")]}),
         ('Presented in collaboration with the Oxford Bengali Cultural Association. ', {'entities': [( 13 , 26 , 'soft_skills')]}),
         ('Rock musicians are working in collaboration with an orchestra to create a new opera. ', {'entities': [( 30 , 43 , 'soft_skills')]}),
         ('Creative collaboration occurs in other arts as well. ', {'entities': [( 9 , 22 , 'soft_skills')]}),
         ('The project has involved collaboration with the geography department. ', {'entities': [( 25 , 38 , 'soft_skills')]}),
         ('The company is building the centre in collaboration with the Institute of Offshore Engineering. ', {'entities': [( 38 , 51 , 'soft_skills')]}),
         ('Close collaboration between the Bank and the Fund is not merely desirable, it is essential. ', {'entities': [( 6 , 19 , 'soft_skills')]}),
         ('The two companies are working in close collaboration each other. ', {'entities': [( 39 , 52 , 'soft_skills')]}),
         ('Empathy was crucial for managing diversity among subordinates. ', {'entities': [( 0 , 7 , 'soft_skills')]}),
         ('Empathy is another crucial ingredient when establishing rapport. ', {'entities': [( 0 , 7 , 'soft_skills')]}),
         ('You have a creative streak-very dangerous when coupled with empathy. ', {'entities': [( 60 , 67 , 'soft_skills')]}),
         ('What she probably needs much more is your empathy and appreciation. ', {'entities': [( 42 , 49 , 'soft_skills')]}),
         ("This helps to develop empathy - the ability to see things from the other's point of view in addition to one's own.", {'entities': [( 22 , 29 , 'soft_skills')]}),
         ('They feel empathy for what he felt. ', {'entities': [( 10 , 17 , 'soft_skills')]}),
         ('It is important to develop the empathy between dogs and their handlers. ', {'entities': [( 31 , 38 , 'soft_skills')]}),
         ('She had great empathy with people. ', {'entities': [( 14 , 21 , 'soft_skills')]}),
         ('I felt real empathy for my mother and what she had been through. ', {'entities': [( 12 , 19 , 'soft_skills')]}),
         ('It is up to Europe to take on the mantle of leadership in environmental issues. ', {'entities': [( 44 , 54 , 'soft_skills')]}),
         ('It is wishful thinking to expect deeper change under his leadership. ', {'entities': [( 57 , 67 , 'soft_skills')]}),
         ('Strong leadership skills. ', {'entities': [( 7 , 17 , 'soft_skills')]}),
         ('The leadership has been unwilling to follow through the implications of these ideas. ', {'entities': [( 4 , 14 , 'soft_skills')]}),
         ('He is a manager capable of leadership. ', {'entities': [( 27 , 37 , 'soft_skills')]}),
         ('He was praised for his firm leadership. ', {'entities': [( 28 , 38 , 'soft_skills')]}),
         ('His confident leadership inspired his followers. ', {'entities': [( 14 , 24 , 'soft_skills')]}),
         ('John has taken the leadership of the football team. ', {'entities': [( 19 , 29 , 'soft_skills')]}),
         ('Teamwork is a key feature of the training programme. ', {'entities': [( 0 , 8 , 'soft_skills')]}),
         ('Teamwork is required in order to achieve these aims. ', {'entities': [( 0 , 8 , 'soft_skills')]}),
         ('Talent wins games, but teamwork and intelligence wins championships.', {'entities': [( 23 , 31 , 'soft_skills')]}),
         ('Excellent teamwork from our staff has brought improvement on all fronts .', {'entities': [( 10 , 18 , 'soft_skills')]}),
         ('Her determination, teamwork skills and leadership capabilities convinced us that she was perfect for the job ', {'entities': [( 19 , 27 , 'soft_skills')]}),
         ('Good teamwork is a powerful tool for effective management. ', {'entities': [( 5 , 13 , 'soft_skills')]}),
         ('We want to encourage good teamwork and communication. ', {'entities': [( 26 , 34 , 'soft_skills')]}),
         ('Brilliant teamwork and old fashioned grit got the team a last minute point. ', {'entities': [( 10 , 18 , 'soft_skills')]}),
         ('Only teamwork will enable us to get the job done on time. ', {'entities': [( 5 , 13 , 'soft_skills')]}),
         ('To illustrate my point I have done a comparative analysis. ', {'entities': [( 49 , 57 , 'soft_skills')]}),
         ('It is difficult to take issue with his analysis. ', {'entities': [( 39 , 47 , 'soft_skills')]}),
         ('His analysis of the problem showed great perception. ', {'entities': [( 4 , 12 , 'soft_skills')]}),
         ("The documentary's treatment/analysis of the issues was very superficial.", {'entities': [( 28 , 36 , 'soft_skills')]}),
         ('The analysis showed a few grains of arsenic in the solution. ', {'entities': [( 4 , 12 , 'soft_skills')]}),
         ('The law requires a detailed analysis of the potential impact on the environment of a proposed project. ', {'entities': [( 28 , 36 , 'soft_skills')]}),
         ('They carried out an in-depth analysis of the results. ', {'entities': [( 29 , 37 , 'soft_skills')]}),
         ('Further analysis of the data is needed. ', {'entities': [( 8 , 16 , 'soft_skills')]}),
         ('Creativity and originality are more important than technical skill. ', {'entities': [( 0 , 10 , 'soft_skills')]}),
         ('We must harness the skill and creativity of our workforce.', {'entities': [(30 , 40 , 'soft_skills')]}),
         ('Becoming your own person releases your creativity. ', {'entities': [(39 , 49 , 'soft_skills')]}),
         ('People with creativity are seldom found nowdays.', {'entities': [(12 , 22 , 'soft_skills')]}),
         ("We're looking for young people with enterprise and creativity.", {'entities': [(51 , 61 , 'soft_skills')]}),
         ('Communication with other countries was difficult during the telephone and postal strike. ', {'entities': [( 1 , 14 , 'soft_skills')]}),
         ('Good people management and communication skills. ', {'entities': [( 27 , 40 , 'soft_skills')]}),
         ('Initiative, independent and good communication skill. ', {'entities': [( 33 , 46 , 'soft_skills')]}),
         ('Good communication is vital in a large organization. ', {'entities': [( 5 , 18 , 'soft_skills')]}),
         ('Mass communication sometimes arouses resistance. ', {'entities': [( 5 , 18 , 'soft_skills')]}),
         ('Good communication is important for business. ', {'entities': [( 5 , 18 , 'soft_skills')]}),
         ('Formal communication channels are usually vertical. ', {'entities': [( 7 , 20 , 'soft_skills')]}),
         ('Employees need to be self-starters with higher than normal creativity and problem solving skills because a supervisor is not nearby. ', {'entities': [( 74 , 89 , 'soft_skills')]}),
         ('The interpretation of these posters, at least on first reading, required a certain amount of problem solving activity. ', {'entities': [( 93 , 108 , 'soft_skills')]}),
         ('They deal with the whole problem solving process from problem sensed to problem overcome. ', {'entities': [( 25 , 40 , 'soft_skills')]}),
         ('In essence problem solving presents a new and challenging angle on a site or feature.Job sharers scored high marks on problem solving, team work and flexibility and demonstrated greater resilience in the face of setbacks. ', {'entities': [( 11 , 26 , 'soft_skills')]}),
         ('The assessment of learning outcomes related to problem solving and personal qualities requires mathematics to be undertaken in context. ', {'entities': [( 47 , 62 , 'soft_skills')]}),
         ('The apes are exhibiting previously unknown resources of problem solving[Sentencedict.com ], and the experiments will doubtless continue. ', {'entities': [( 56 , 71 , 'soft_skills')]}),
         ('These support problem solving techniques such as rule-based systems, genetic optimisation and fuzzy logic. ', {'entities': [( 14 , 29 , 'soft_skills')]}),
         ('But an important aspect of problem solving is retrospection.', {'entities': [( 27 , 42 , 'soft_skills')]}),
         ('You need to systematize your approach to problem solving', {'entities': [( 41 , 56 , 'soft_skills')]}),
         ('Published reports and dashboards using Power BI.', {'entities': [( 39 , 47 , 'hard_skills')]}),
         ('Explore data in a Variety of ways and across multiple visualizations using Power BI.', {'entities': [( 75 , 83 , 'hard_skills')]}),
         ('Used Power BI, Power Pivot to develop data analysis prototype, and used Power View and Power Map to visualize reports.', {'entities': [( 5 , 13 , 'hard_skills')]}),
         ('Generated computed tables in Power BI by using Dax.', {'entities': [( 29 , 37 , 'hard_skills')]}),
         ('Strong Knowledge on Power BI to import data from various sources.', {'entities': [( 20 , 28 , 'hard_skills')]}),
         ('These collective systems have evolved by means of natural SELECTION to exhibit striking problem solving capacities ', {'entities': [( 88 , 103 , 'soft_skills')]}),
         ('Many tech startups recognize this truth-there seems to be a new, great problem solving app born every day.', {'entities': [( 71 , 86 , 'soft_skills')]}),
         ("Don't believe that all the good, problem solving ideas have been taken.", {'entities': [( 33 , 48 , 'soft_skills')]}),
         ('The fun never ends and neither does its ability to hone your logic and problem solving skills to razor sharpness. ', {'entities': [( 71 , 86 , 'soft_skills')]}),
         ('Communicate clearly and concisely ', {'entities': [( 0 , 11 , 'soft_skills')]}),
         ('Excellent communication, leadership, motivational skills and can interact effectively with clients, business prospects and staff ', {'entities': [( 10 , 23 , 'soft_skills'),( 25 , 35 , 'soft_skills')]}),
         ('Well developed skills in prioritizing, organization, decision making, time management, and verbal/written communication skills ', {'entities': [( 25 , 37 , 'soft_skills'),( 53 , 68 , 'soft_skills'),( 70 , 85 , 'soft_skills'),( 106 , 119 , 'soft_skills')]}),
         ('Excellent written and verbal communication skills ', {'entities': [( 29 , 42 , 'soft_skills')]}),
         ('Become a core resource in Tableau expertise for the Digital Analytics team', {'entities': [(26 , 33 , 'hard_skills')]}),
         ('Utilize best practice principles in designing and conceptualizing Tableau dashboards from business requirements ', {'entities': [( 66 , 73 , 'hard_skills')]}),
         ('Research underlying data and define an approach using SQL, SAS, and Tableau capabilities for enabling access and performance ', {'entities': [( 54 , 57 , 'hard_skills'),( 59 , 62 , 'hard_skills'),( 68 , 75 , 'hard_skills')]}),
         ('Experience developing reports and making recommendations, using BI software such as SAS, OBIEE, Tableau.', {'entities': [( 84 , 87 , 'hard_skills'), ( 96 , 103 , 'hard_skills')]}),
         ('The Senior Risk Quant SAS Developer will design and develop robust automated solutions in partnership with stakeholders in Risk and Finance', {'entities': [( 22 , 25 , 'hard_skills')]}),
         ('Execute change management processes surrounding new releases of SAS functionality.', {'entities': [( 64 , 67 , 'hard_skills')]}),
         ('Evaluate and recommend new tools and methodologies to assist with change management and perform upgrades of the SAS environment when necessary.', {'entities': [( 112 , 115 , 'hard_skills')]}),
         ('Conducting data research using the latest data mining and data manipulation applications', {'entities': [( 42 , 53 , 'hard_skills')]}),
         ('Work closely with data mining team to ensure reporting database is monitored / maintained daily.', {'entities': [( 18 , 29 , 'hard_skills')]}),
         ('Building predictive models using data mining methodologies along with analyzing and mining business data to identify patterns and correlations among the various data points ', {'entities': [( 9 , 26 , 'hard_skills'),( 33 , 44 , 'hard_skills')]}),
         ('Manage the Data warehouse and provide database and data mining technical support ', {'entities': [( 51 , 62 , 'hard_skills')]}),
         ('Research & develop Machine Learning models for security problems, in the areas of Networking, Application & Data', {'entities': [( 19 , 35 , 'hard_skills')]}),
         ('Develop new machine learning models to detect malicious activity on mobile devices.', {'entities': [( 12 , 28 , 'hard_skills')]}),
         ('Knowledge of one or more open-source Machine Learning framework.', {'entities': [( 37 , 53 , 'hard_skills')]}),
         ('Strong knowledge of data structures, algorithms, operating systems, and distributed systems fundamentals.', {'entities': [( 20 , 35 , 'hard_skills'),( 37 , 47 , 'hard_skills')]}),
         ('Understanding of data structures and algorithms.', {'entities': [( 17 , 32 , 'hard_skills'), ( 37 , 47 , 'hard_skills')]}),
         ('Worked on Shiny and R application showcasing machine learning.', {'entities': [( 20 , 21 , 'hard_skills'), (45 , 61 , 'hard_skills')]}),
         ('Worked on R packages.', {'entities': [( 10 , 11 , 'hard_skills')]}),
         ('Formulated procedures for integration of R programming plans with data sources and delivery systems.', {'entities': [( 41 , 42 , 'hard_skills')]}),
         ('Prepared scripts to ensure proper data access, manipulation and reporting functions with R programming languages.', {'entities': [( 89 , 90 , 'hard_skills')]}),
         ('Assisted in pricing of securities including bonds and mortgages in programming domain such as C++, Matlab and R programming.', {'entities': [( 94 , 97 , 'hard_skills'),( 99 , 105 , 'hard_skills'),( 109 , 110 , 'hard_skills')]}),
         ('I have done two projects Healthcare & E- Commerce on R programming', {'entities': [( 53 , 54 , 'hard_skills')]}),
         ('Server-based Node.js development.', {'entities': [( 13 , 20 , 'hard_skills')]}),
         ('Write content for blogs and other outlets on Node.js', {'entities': [( 45 , 52 , 'hard_skills')]}),
         ('At least 2+ years of experience programming with Node.js', {'entities': [( 49 , 56 , 'hard_skills')]}),
         ('Experience with database abstraction libraries and ORMs especially those from the Node.js world', {'entities': [( 82 , 89 , 'hard_skills')]}),
         ('Strong understanding of Node.JS internals and systems', {'entities': [( 24 , 31 , 'hard_skills')]}),
         ('Experience working as a backend developer, developing in Node.JS', {'entities': [( 57 , 64 , 'hard_skills')]}),
         ('In-depth knowledge of XML and XSLT data and processing tools.', {'entities': [( 22 , 25 , 'hard_skills'), ( 30 , 34 , 'hard_skills')]}),
         ('Remain current on all new updates and programs available XML programming.', {'entities': [( 57 , 60 , 'hard_skills')]}),
         ('Develop new applications using XML DotNet and other programming software available.', {'entities': [( 31 , 34 , 'hard_skills')]}),
         ('Write technical guides to XML applications.', {'entities': [( 26 , 29 , 'hard_skills')]}),
         ('Experience with multivariate regression, logistic regression, and cluster analysis.', {'entities': [( 29 , 39 , 'hard_skills'), ( 74 , 82 , 'hard_skills')]}),
         ('Basic statistical knowledge including regression', {'entities': [( 38 , 48 , 'hard_skills')]}),
         ('Develop Regression/Tree based models to support the database marketing efforts of co-op members and clients.', {'entities': [( 8 , 18 , 'hard_skills')]}),
         ('Thorough understanding of basic statistical methods such as hypothesis testing, linear regression, etc.', {'entities': [( 60 , 78 , 'hard_skills'), ( 87 , 97 , 'hard_skills')]}),
         ('Independently conducts rigorous statistical analysis, including statistical modeling, multiple regressions', {'entities': [( 95 , 105 , 'hard_skills')]}),
         ('Possess familiarity with various programming languages, including C, C++, MATLAB, Core Java, SQL and FORTRAN', {'entities': [( 74 , 80 , 'hard_skills')]}),
         ('Followed instructions from lead developer to explore and develop user interfaces for data pre-processing and data analysis in Matlab', {'entities': [( 126 , 132 , 'hard_skills')]}),
         ('Implementing algorithms from Matlab into C++ on embedded solutions and optimizing performance on VLIW/SIMD cores for maximum throughput and lowest latency', {'entities': [( 29 , 35 , 'hard_skills')]}),
         ('Creating new web services using Matlab and other programming languages to support integration with other development systems', {'entities': [( 32 , 38 , 'hard_skills')]}),
         ('Designed various applications using GUIs, C++, Matlab and developed multiple gaming applications like Stellaria, classic board game Risk etc. to increase the download percentage from Android PlayStore', {'entities': [( 47 , 53 , 'hard_skills')]}),
         ('Coordinated with other programmers to develop cutting edge web applications as per client specifications using HTML, JavaScript and Matlab', {'entities': [( 132 , 138 , 'hard_skills')]}),
         ('Support cross-functional projects & initiatives requiring forecasting or scoring expertise to drive business strategy execution', {'entities': [( 58 , 69 , 'hard_skills')]}),
         ('Support the development of forecasting & scoring models for risk management and business planning purposes', {'entities': [( 27 , 38 , 'hard_skills')]}),
         ('Experience with Walt Disney Parks & Resorts forecasting and planning processes', {'entities': [( 44 , 55 , 'hard_skills')]}),
         ('3+ years in forecasting, supply chain, retail planning, or other relevant analytical roles', {'entities': [( 12 , 23 , 'hard_skills')]}),
         ('Develop and own modifying financial models for re-forecasting and scenario analysis purposes', {'entities': [( 50 , 61 , 'hard_skills')]}),
         ('Assist with the forecasting and analysis process', {'entities': [( 16 , 27 , 'hard_skills')]}),
         ('Web page layout hard_skills using HTML, CSS, XML/XSLT', {'entities': [( 35 , 38 , 'hard_skills')]}),
         ('Knowledge of developing Rich interface application using Adobe FLEX (Alternatively proficiency in HTML5, CSS3, jQuery, AJAX and WEB design/developmentis also acceptable. )', {'entities': [( 105 , 108 , 'hard_skills')]}),
         ('HTML5, CSS, and JavaScript', {'entities': [( 7 , 10 , 'hard_skills')]}),
         ('Advanced HTML5, CSS3 and JavaScript hard_skills necessary', {'entities': [( 16 , 19 , 'hard_skills')]}),
         ('3 years experience with HTML and CSS', {'entities': [( 33 , 36 , 'hard_skills')]}),
         ('Experience with ColdFusion or SQL, CSS, CMS a plus', {'entities': [( 35 , 38 , 'hard_skills')]}),
         ('Strong experience in JSON , HTML5 , Angular JS', {'entities': [( 28 , 32 , 'hard_skills')]}),
         ('Experience with HTML, as well as some knowledge of Dreamweaver, as this role owns the intranet portal for practitioners', {'entities': [( 16 , 20 , 'hard_skills')]}),
         ('Proficient in HTML5 Development', {'entities': [( 14 , 18 , 'hard_skills')]}),
         ('Working knowledge in Java, JavaScript, HTML and CSS', {'entities': [( 39 , 43 , 'hard_skills')]}),
         ("Then there's HTML circa Netscape Navigator 2.0.", {'entities': [( 13 , 17 , 'hard_skills')]}),
         ('No more need to learn HTML, or hypertext markup language.', {'entities': [( 22 , 26 , 'hard_skills')]}),
         ('Java Script is a pre-emptive strike against Microsoft, which next week will unveil its own Internet software program code-named Blackbird.', {'entities': [( 0 , 11 , 'hard_skills')]}),
         ('Students, who have internships at companies in Boston, learn HTML and Java Script as well as the computer language, ColdFusion.', {'entities': [( 70 , 81 , 'hard_skills')]}),
         ('It also is announcing Visual Basic Script to compete with easy-to-use Java Script from Netscape and Sun.', {'entities': [( 70 , 81 , 'hard_skills')]}),
         ('On Monday, Sun Microsystems and Netscape will announce a dumbed-down version of the program called Java Script, sources say.', {'entities': [( 99 , 110 , 'hard_skills')]}),
         ('Netscape wrote the Java Script program but it will carry the Sun name.', {'entities': [( 19 , 30 , 'hard_skills')]}),
         ('The 36-year-old San Francisco resident repairs Java script and writes HTML code.', {'entities': [( 47 , 58 , 'hard_skills')]}),
         ('The latest version of MayaVi, called Mayavi2, is a component of the Enthought suite of scientific Python programs.', {'entities': [( 98 , 113 , 'hard_skills')]}),
         ('Gadfly allows Python programs to store, retrieve and query tabular data without having to rely on any external database engine or package.', {'entities': [( 14 , 29 , 'hard_skills')]}),
         ('Python programs are easy to read yet the code are very compact so you get much done with little code to write.', {'entities': [( 0 , 15 , 'hard_skills')]}),
         ('It can generate stand-alone programs or extension modules that can be imported and used in larger Python programs.', {'entities': [( 98 , 113 , 'hard_skills')]}),
         ('PyGObject provides a wrapper for use in Python programs when accessing GObject libraries.', {'entities': [( 40 , 55 , 'hard_skills')]}),
         ('Additionally, the Canopy IDE is also an option for writing Python programs.', {'entities': [( 59 , 74 , 'hard_skills')]}),
         ('Master Data Services first shipped with Microsoft SQL Server 2008 R2.', {'entities': [( 50 , 53 , 'hard_skills')]}),
         ('The Enterprise edition used Microsoft SQL Server as its database engine.', {'entities': [( 38 , 41 , 'hard_skills')]}),
         ('Some SQL DBMSs implement vendor-specific functions similar to COALESCE.', {'entities': [( 5 , 8 , 'hard_skills')]}),
         ('Customer software can use the database with object and SQL code.', {'entities': [( 55 , 58 , 'hard_skills')]}),
         ('Clarion supports both SQL databases and non-SQL data stores.', {'entities': [( 22 , 25 , 'hard_skills')]}),
         ('SQL Server acts as the data librarian of a computer network.', {'entities': [( 0 , 3 , 'hard_skills')]}),
         ('The firewall script runs on every PHP document on the server.', {'entities': [( 34 , 37 , 'hard_skills')]}),
         ('Globule also supports the replication of PHP documents accessing MySQL databases.', {'entities': [( 41 , 44 , 'hard_skills')]}),
         ('497 Google count All results are from php script directoy listings.', {'entities': [( 38 , 41 , 'hard_skills')]}),
         ('It is written in PHP and uses a MySQL database server.', {'entities': [( 17 , 20 , 'hard_skills')]}),
         ('Many languages support this including PHP, bash scripts and perl.', {'entities': [( 38 , 41 , 'hard_skills')]}),
         ('Most web hosting providers support PHP for use by their clients.', {'entities': [( 35 , 38 , 'hard_skills')]}),
         ("And it could happen if you use Microsoft Word 98 for Macintosh", {"entities": [(31 , 45 , 'hard_skills')]}),
         ("First released for Lotus 1-2-3 and later also for Microsoft Excel.", {"entities": [(50 , 65 , 'hard_skills')]}),
         ("So really impressive Java programs will still require faster Internet connections.", {"entities": [(21 , 25 , 'hard_skills')]}),
         ("The Java computer language has been hailed as an Internet innovation.", {"entities": [(4 , 8 , 'hard_skills')]}),
         ("Intel sees Java as a key building block, he said.", {"entities": [(11 , 15 , 'hard_skills')]}),
         ("Schmidt said at an industry conference on Java in New York.", {"entities": [(42 , 46 , 'hard_skills')]}),
         ('Sun Microsystems Inc . has a competitive programming language, Java.', {'entities': [( 63 , 67 , 'hard_skills')]}),
         ('So a rogue Java program could seize control of the computer.', {'entities': [( 11 , 15 , 'hard_skills')]}),
         ('Java enables developers to embed mini-programs into Web pages.', {'entities': [( 0 , 4 , 'hard_skills')]}),
         ('Over 4 plus years of experience with Machine Learning using R language and Python.', {'entities': [( 37 , 53 , 'hard_skills'),( 60 , 61 , 'hard_skills'), (75 , 81 , 'hard_skills')]}),
         ('Implementing client-server, web and desktop-based applications using C/C++ language.', {'entities': [(69 , 74 , 'hard_skills')]}),
         ('Self- directed, detail-oriented, and professional C++ programmer', {'entities': [(50 , 53 , 'hard_skills')]}),
         ('Thorough knowledge of C/C++ programming concepts.', {'entities': [(22 , 27 , 'hard_skills')]}),
         ('Knowledge of advanced level programming in C/C++ including thread synchronization multithreading', {'entities': [( 43 , 48 , 'hard_skills')]}),
         ('Developed highly efficient algorithms in C++ through both pair-programming and independent work.', {'entities': [( 41 , 44 , 'hard_skills')]}),
         ('Specified, prototyped, developed and tested an object-oriented, multiplatform C++ framework.', {'entities': [( 78 , 81 , 'hard_skills')]}),
         ('Debugging and investigating issues utilizing C++ on the client server.', {'entities': [( 45 , 48 , 'hard_skills')]}),
         ('C/C++ developer with experience in Object Oriented Analysis and Design', {'entities': [( 0 , 5 , 'hard_skills')]}),
         ('Setting up and optimising Google Analytics properties and views in line with current product structure.', {'entities': [(26 , 42 , 'hard_skills')]}),
         ('Strong knowledge of Google Analytics, as well as other analytics apps. ', {'entities': [( 20 , 36 , 'hard_skills')]}),
         ('Building dashboards/customer segmentations, designing/analyzing digital marketing campaigns using Google Analytics', {'entities': [( 98 , 114 , 'hard_skills')]}),
         ('Setting up and optimising Google Analytics properties and views in line with current product structure.', {'entities': [( 26 , 42 , 'hard_skills')]}),
         ('Hands-on experience with Google Analytics.', {'entities': [( 25 , 41 , 'hard_skills')]}),
         ('Proficient in configuring Google Analytics features.', {'entities': [( 26 , 42 , 'hard_skills')]}),
         ('Build infrastructure using Hadoop’s core components such as HBase, Kafka, and Hive', {'entities': [( 60 , 65 , 'hard_skills'),(67 , 72 , 'hard_skills'),( 78 , 82 , 'hard_skills') ]}),
         ('Hands on experience with Running Pig and Hive Queries. ', {'entities': [( 33 , 36 , 'hard_skills'),( 41 , 45 , 'hard_skills')]}),
         ('Analyzing data with Hive, Pig and HBase Data scrubbing and processing with Oozie.', {'entities': [( 20 , 24 , 'hard_skills'), (26 , 29 , 'hard_skills'), ( 34 , 39 , 'hard_skills')]}),
         ('Develop data solutions with Big Data technologies such as Hive.', {'entities': [( 58 , 62 , 'hard_skills')]}),
         ('Experience working in Hive or related tools on Hadoop.', {'entities': [( 22 , 26 , 'hard_skills')]}),
         ('Slide shows using Microsoft PowerPoint, displayed on a big screen in front.', {'entities': [(18 , 38 , 'hard_skills')]}),
         ('It is also supported by GIMP, Google Chrome, Microsoft PowerPoint and Microsoft Word.', {'entities': [(45 , 65 , 'hard_skills'), ( 70 , 84 , 'hard_skills')]}),
         ('Some applications commonly used with the Smart Board are Microsoft PowerPoint, Word, and AutoCAD.', {'entities': [(57 , 77 , 'hard_skills'), (89 , 96 , 'hard_skills')]}),
         ('It is also used for the conversion of Microsoft PowerPoint presentations into elearning content.', {'entities': [( 38 , 58 , 'hard_skills')]}),
         ('Issue concerns use of Microsoft Powerpoint clip art.', {'entities': [( 22 , 42 , 'hard_skills')]}),
         ('Formats of files supported include Avi files, Microsoft Excel, Microsoft Powerpoint, Microsoft Word, Adobe PDF, MPEG-4 files.', {'entities': [( 46 , 61 , 'hard_skills'),( 63 , 83 , 'hard_skills'), ( 85 , 99 , 'hard_skills')]}),
         ('The software runs on Microsoft Access which operates only on Microsoft Windows.', {'entities': [( 21 , 37 , 'hard_skills')]}),
         ('That is what Microsoft Access is designed for.', {'entities': [( 13 , 29 , 'hard_skills')]}),
         ("The alliance gives Microsoft access to MCI's 20 million residential and business customers.", {'entities': [(19 , 35 , 'hard_skills')]}),
         ('In November, Microsoft released the first version of their popular database software Microsoft Access.', {'entities': [( 85 , 101 , 'hard_skills')]}),
         ('The reporting engine is based on a portable Microsoft Access database.', {'entities': [( 44 , 60 , 'hard_skills')]}),
         ('ASP . NET works really well with Microsoft SQL Server and Microsoft Access.', {'entities': [( 43 , 46 , 'hard_skills'), (58 , 74 , 'hard_skills')]}),
         ('It is written in PHP and uses a MySQL database server.', {'entities': [( 17 , 20 , 'hard_skills'),(32 , 37 , 'hard_skills') ]}),
         ('I have a MySQL database table with about 2 million rows.', {'entities': [(9 , 14 , 'hard_skills')]}),
         ('MySQL database support is added as one such core component.', {'entities': [(0 , 5 , 'hard_skills')]}),
         ('MySQL Cluster is able to support cross-shard queries and transactions.', {'entities': [(0 , 5 , 'hard_skills')]}),
         ('It also supports REPLACE INTO as an alias for compatibility with MySQL. ', {'entities': [( 65 , 70 , 'hard_skills')]}),
         ('OpenSIS is written in PHP and uses MySQL to store information.', {'entities': [(22 , 25 , 'hard_skills'), (35 , 40 , 'hard_skills')]}),
         ("And it could happen if you use Microsoft Word 98 for Macintosh", {"entities": [(31 , 45 , 'hard_skills')]}),
         ("They wrote articles in Microsoft Word and gave the files to Souren.", {"entities": [(23 , 37 , 'hard_skills')]}),
         ("Fortunately, it is possible to change the setting easily with Microsoft Word.", {"entities": [(62 , 76 , 'hard_skills')]}),
         ("Then he pastes his work into Microsoft Word for revisions and corrections.", {"entities": [(29 , 43 , 'hard_skills')]}),
         ("Microsoft Word 97 shows my name as the licensee in the opening window.", {"entities": [(0 , 14 , 'hard_skills')]}),
         ("Fujitsu offers Microsoft Word, Excel and Office with some models of PC.", {"entities": [(15 , 29 , 'hard_skills')]}),
         ("If you have Microsoft Word on your computer, go to it.", {"entities": [(12 , 26 , 'hard_skills')]}),
         ("A complete and up-to-date index in Microsoft Excel format is available online.", {"entities": [(35 , 50 , 'hard_skills')]}),
         ("The main syntax for the formulation of rules adopts the Microsoft Excel format.", {"entities": [(56 , 71 , 'hard_skills')]}),
         ("It is a built-in feature of Microsoft Excel and Microsoft Access.", {"entities": [(28 , 43 , 'hard_skills')]}),
         ("If you are an accountant you are probably familiar with Microsoft Excel.", {"entities": [(56 , 71 , 'hard_skills')]}),
         ("First released for Lotus 1-2-3 and later also for Microsoft Excel.", {"entities": [(50 , 65 , 'hard_skills')]}),
         ("Reports can be exported to Microsoft Excel or saved as Excel-compatible HTML files.", {"entities": [(27 , 42 , 'hard_skills'), (72 , 76 , 'hard_skills')]}),
         ("My wife and I use Microsoft Outlook Express as our e-mail client.", {"entities": [(18 , 35 , 'hard_skills')]}),
         ("It was one of few readers that integrated directly with Microsoft Outlook.", {"entities": [(56 , 73 , 'hard_skills')]}),
         ("Almost immediately, my copy of Microsoft Outlook turned into Microsoft Look Out.", {"entities": [(31 , 48 , 'hard_skills')]}),
         ("It spreads primarily through Microsoft Outlook e-mail software on Windows computers.", {"entities": [(29 , 46 , 'hard_skills')]}),
         ("In Microsoft Outlook, time stamps are therefore stored and communicated without DST offsets.", {"entities": [(3 , 20 , 'hard_skills')]}),
         ("America Online and Microsoft Outlook Express offer subscribers a similar function, Rampell said.", {"entities": [(19 , 36 , 'hard_skills')]}),
]

# %%
import spacy
# Loading pre-defined language model from Spacy
nlp = spacy.load('en_core_web_sm')
nlp.pipe_names

# Writing a small function to get the position of the target word in a sentence
def get(sentence, target):
    start_index = sentence.find(target)
    end_index = start_index + len(target)
    print("'", sentence, "', {'entities': [(", start_index, ",", end_index, ",", "'soft_skills')]}")

for data in train:
    sentence, _ = data
    get(sentence, 'collaboration')

# Rest of your code
# Out:
# ' Skilled with Wrike and AtTask project management software.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Expert knowledge of SQL and relational database management systems.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Proficient in Microsoft Office (Word, Excel, Outlook, PowerPoint, Visio).  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Provided technical leadership and training to ensure on time and in budget project delivery  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Experienced at managing relational and non-relational database software such as MySQL, SQLite3, Mongo DB, and JSON  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Proficient in PHP, Ruby on Rails, Java, C++, and Python  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Used predictive analytics such as machine learning and data mining techniques to forecast company sales of new products with a 95% accuracy rate  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Improved data mining processes, resulting in a 20% decrease in time needed to infer insights from customer data used to develop marketing strategies  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Used advanced Microsoft Excel to create pivot tables, used VLOOKUP, and other Excel functions ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Data Scientist with 4+ years of experience executing data-driven solutions to increase efficiency, accuracy, and utility of internal data processing.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Experienced at creating data regression models, using predictive data modeling, and analyzing data mining algorithms to deliver insights and implement action-oriented solutions to complex business problems.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Increased accessibility and usability of customer data by redesigning data visualization techniques to include statistical graphs and information graphics  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Utilized web scraping techniques to extract and organize competitor data  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Conducted a data regression analysis of the relationship between company stock prices and industry trends, achieving a 15% more accurate prediction of performance than previous years  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Used statistical techniques for hypothesis testing to validate data and interpretations ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Designed and built statistical analysis models on large data sets (e.g., Aster, Teradata) that helped increase online sales (up to 15% per product) and lowered cart-abandonment rate by 23%. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Created visually impactful dashboards in Excel and Tableau for data reporting by using pivot tables and VLOOKUP. Extracted, interpreted and analyzed data to identify key metrics and transform raw data into meaningful, actionable information. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Conduct data mining, data modeling, statistical analysis, business intelligence gathering, trending and benchmarking. Data analytics supports decisions for high-priority, enterprise initiatives involving IT/product development, customer service improvement, organizational realignment and process reengineering. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Research and develop state of the art techniques in the field of computer vision, ML and DL  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Research and develop deep learning algorithms  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Research & develop Machine Learning models for security problems, in the areas of Networking, Application & Data  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Develop new machine learning models to detect malicious activity on mobile devices ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Design, conduct, and report results from prototype or proof-of-concept research projects that focus on 1) new tools, methods, or algorithms, 2) new scientific domains or application areas, or 3) new data sets or sources  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Work with every investment team in MBFI (Credit, Macro, Equities, RV, Securitized, Mid-horizon etc.) to introduce cutting-edge techniques and innovative data sources across the Fund  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Create innovative, systematic investment signals and strategies based on a rigorous, peer-reviewed research process  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Develop the teams capabilities in data science and machine-learning, and apply them to create new data-driven insights  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' This role will suit you if you thrive on working in a fast paced environment where your work has high impact  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Work closely with development teams to ensure accurate integration of machine learning models into firm platforms  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Presented in collaboration with the Oxford Bengali Cultural Association.  ', {'entities': [( 13 , 26 , 'soft_skills')]}
# ' Rock musicians are working in collaboration with an orchestra to create a new opera.  ', {'entities': [( 30 , 43 , 'soft_skills')]}
# ' Creative collaboration occurs in other arts as well.  ', {'entities': [( 9 , 22 , 'soft_skills')]}
# ' The project has involved collaboration with the geography department.  ', {'entities': [( 25 , 38 , 'soft_skills')]}
# ' The company is building the centre in collaboration with the Institute of Offshore Engineering.  ', {'entities': [( 38 , 51 , 'soft_skills')]}
# ' Close collaboration between the Bank and the Fund is not merely desirable, it is essential.  ', {'entities': [( 6 , 19 , 'soft_skills')]}
# ' The two companies are working in close collaboration each other.  ', {'entities': [( 39 , 52 , 'soft_skills')]}
# ' Empathy was crucial for managing diversity among subordinates.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Empathy is another crucial ingredient when establishing rapport.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' You have a creative streak-very dangerous when coupled with empathy.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' What she probably needs much more is your empathy and appreciation.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' This helps to develop empathy - the ability to see things from the other's point of view in addition to one's own. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' They feel empathy for what he felt.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' It is important to develop the empathy between dogs and their handlers.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' She had great empathy with people.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' I felt real empathy for my mother and what she had been through.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' It is up to Europe to take on the mantle of leadership in environmental issues.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' It is wishful thinking to expect deeper change under his leadership.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Strong leadership skills.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' The leadership has been unwilling to follow through the implications of these ideas.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' He is a manager capable of leadership.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' He was praised for his firm leadership.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' His confident leadership inspired his followers.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' John has taken the leadership of the football team.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Teamwork is a key feature of the training programme.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Teamwork is required in order to achieve these aims.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Talent wins games, but teamwork and intelligence wins championships. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Excellent teamwork from our staff has brought improvement on all fronts . ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Her determination, teamwork skills and leadership capabilities convinced us that she was perfect for the job  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Good teamwork is a powerful tool for effective management.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' We want to encourage good teamwork and communication.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Brilliant teamwork and old fashioned grit got the team a last minute point.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Only teamwork will enable us to get the job done on time.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' To illustrate my point I have done a comparative analysis.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' It is difficult to take issue with his analysis.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' His analysis of the problem showed great perception.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' The documentary's treatment/analysis of the issues was very superficial. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' The analysis showed a few grains of arsenic in the solution.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' The law requires a detailed analysis of the potential impact on the environment of a proposed project.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' They carried out an in-depth analysis of the results.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Further analysis of the data is needed.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Creativity and originality are more important than technical skill.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' We must harness the skill and creativity of our workforce. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Becoming your own person releases your creativity.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' People with creativity are seldom found nowdays. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' We're looking for young people with enterprise and creativity. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Communication with other countries was difficult during the telephone and postal strike.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Good people management and communication skills.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Initiative, independent and good communication skill.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Good communication is vital in a large organization.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Mass communication sometimes arouses resistance.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Good communication is important for business.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Formal communication channels are usually vertical.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Employees need to be self-starters with higher than normal creativity and problem solving skills because a supervisor is not nearby.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' The interpretation of these posters, at least on first reading, required a certain amount of problem solving activity.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' They deal with the whole problem solving process from problem sensed to problem overcome.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' In essence problem solving presents a new and challenging angle on a site or feature.Job sharers scored high marks on problem solving, team work and flexibility and demonstrated greater resilience in the face of setbacks.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' The assessment of learning outcomes related to problem solving and personal qualities requires mathematics to be undertaken in context.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' The apes are exhibiting previously unknown resources of problem solving[Sentencedict.com ], and the experiments will doubtless continue.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' These support problem solving techniques such as rule-based systems, genetic optimisation and fuzzy logic.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' But an important aspect of problem solving is retrospection. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' You need to systematize your approach to problem solving ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Published reports and dashboards using Power BI. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Explore data in a Variety of ways and across multiple visualizations using Power BI. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Used Power BI, Power Pivot to develop data analysis prototype, and used Power View and Power Map to visualize reports. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Generated computed tables in Power BI by using Dax. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Strong Knowledge on Power BI to import data from various sources. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' These collective systems have evolved by means of natural SELECTION to exhibit striking problem solving capacities  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Many tech startups recognize this truth-there seems to be a new, great problem solving app born every day. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Don't believe that all the good, problem solving ideas have been taken. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' The fun never ends and neither does its ability to hone your logic and problem solving skills to razor sharpness.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Communicate clearly and concisely  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Excellent communication, leadership, motivational skills and can interact effectively with clients, business prospects and staff  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Well developed skills in prioritizing, organization, decision making, time management, and verbal/written communication skills  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Excellent written and verbal communication skills  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Become a core resource in Tableau expertise for the Digital Analytics team ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Utilize best practice principles in designing and conceptualizing Tableau dashboards from business requirements  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Research underlying data and define an approach using SQL, SAS, and Tableau capabilities for enabling access and performance  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Experience developing reports and making recommendations, using BI software such as SAS, OBIEE, Tableau. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' The Senior Risk Quant SAS Developer will design and develop robust automated solutions in partnership with stakeholders in Risk and Finance ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Execute change management processes surrounding new releases of SAS functionality. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Evaluate and recommend new tools and methodologies to assist with change management and perform upgrades of the SAS environment when necessary. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Conducting data research using the latest data mining and data manipulation applications ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Work closely with data mining team to ensure reporting database is monitored / maintained daily. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Building predictive models using data mining methodologies along with analyzing and mining business data to identify patterns and correlations among the various data points  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Manage the Data warehouse and provide database and data mining technical support  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Research & develop Machine Learning models for security problems, in the areas of Networking, Application & Data ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Develop new machine learning models to detect malicious activity on mobile devices. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Knowledge of one or more open-source Machine Learning framework. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Strong knowledge of data structures, algorithms, operating systems, and distributed systems fundamentals. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Understanding of data structures and algorithms. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Worked on Shiny and R application showcasing machine learning. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Worked on R packages. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Formulated procedures for integration of R programming plans with data sources and delivery systems. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Prepared scripts to ensure proper data access, manipulation and reporting functions with R programming languages. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Assisted in pricing of securities including bonds and mortgages in programming domain such as C++, Matlab and R programming. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' I have done two projects Healthcare & E- Commerce on R programming ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Server-based Node.js development. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Write content for blogs and other outlets on Node.js ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' At least 2+ years of experience programming with Node.js ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Experience with database abstraction libraries and ORMs especially those from the Node.js world ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Strong understanding of Node.JS internals and systems ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Experience working as a backend developer, developing in Node.JS ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' In-depth knowledge of XML and XSLT data and processing tools. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Remain current on all new updates and programs available XML programming. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Develop new applications using XML DotNet and other programming software available. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Write technical guides to XML applications. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Experience with multivariate regression, logistic regression, and cluster analysis. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Basic statistical knowledge including regression ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Develop Regression/Tree based models to support the database marketing efforts of co-op members and clients. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Thorough understanding of basic statistical methods such as hypothesis testing, linear regression, etc. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Independently conducts rigorous statistical analysis, including statistical modeling, multiple regressions ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Possess familiarity with various programming languages, including C, C++, MATLAB, Core Java, SQL and FORTRAN ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Followed instructions from lead developer to explore and develop user interfaces for data pre-processing and data analysis in Matlab ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Implementing algorithms from Matlab into C++ on embedded solutions and optimizing performance on VLIW/SIMD cores for maximum throughput and lowest latency ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Creating new web services using Matlab and other programming languages to support integration with other development systems ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Designed various applications using GUIs, C++, Matlab and developed multiple gaming applications like Stellaria, classic board game Risk etc. to increase the download percentage from Android PlayStore ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Coordinated with other programmers to develop cutting edge web applications as per client specifications using HTML, JavaScript and Matlab ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Support cross-functional projects & initiatives requiring forecasting or scoring expertise to drive business strategy execution ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Support the development of forecasting & scoring models for risk management and business planning purposes ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Experience with Walt Disney Parks & Resorts forecasting and planning processes ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' 3+ years in forecasting, supply chain, retail planning, or other relevant analytical roles ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Develop and own modifying financial models for re-forecasting and scenario analysis purposes ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Assist with the forecasting and analysis process ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Web page layout hard_skills using HTML, CSS, XML/XSLT ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Knowledge of developing Rich interface application using Adobe FLEX (Alternatively proficiency in HTML5, CSS3, jQuery, AJAX and WEB design/developmentis also acceptable. ) ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' HTML5, CSS, and JavaScript ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Advanced HTML5, CSS3 and JavaScript hard_skills necessary ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' 3 years experience with HTML and CSS ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Experience with ColdFusion or SQL, CSS, CMS a plus ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Strong experience in JSON , HTML5 , Angular JS ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Experience with HTML, as well as some knowledge of Dreamweaver, as this role owns the intranet portal for practitioners ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Proficient in HTML5 Development ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Working knowledge in Java, JavaScript, HTML and CSS ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Then there's HTML circa Netscape Navigator 2.0. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' No more need to learn HTML, or hypertext markup language. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Java Script is a pre-emptive strike against Microsoft, which next week will unveil its own Internet software program code-named Blackbird. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Students, who have internships at companies in Boston, learn HTML and Java Script as well as the computer language, ColdFusion. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' It also is announcing Visual Basic Script to compete with easy-to-use Java Script from Netscape and Sun. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' On Monday, Sun Microsystems and Netscape will announce a dumbed-down version of the program called Java Script, sources say. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Netscape wrote the Java Script program but it will carry the Sun name. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' The 36-year-old San Francisco resident repairs Java script and writes HTML code. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' The latest version of MayaVi, called Mayavi2, is a component of the Enthought suite of scientific Python programs. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Gadfly allows Python programs to store, retrieve and query tabular data without having to rely on any external database engine or package. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Python programs are easy to read yet the code are very compact so you get much done with little code to write. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' It can generate stand-alone programs or extension modules that can be imported and used in larger Python programs. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' PyGObject provides a wrapper for use in Python programs when accessing GObject libraries. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Additionally, the Canopy IDE is also an option for writing Python programs. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Master Data Services first shipped with Microsoft SQL Server 2008 R2. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' The Enterprise edition used Microsoft SQL Server as its database engine. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Some SQL DBMSs implement vendor-specific functions similar to COALESCE. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Customer software can use the database with object and SQL code. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Clarion supports both SQL databases and non-SQL data stores. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' SQL Server acts as the data librarian of a computer network. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' The firewall script runs on every PHP document on the server. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Globule also supports the replication of PHP documents accessing MySQL databases. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' 497 Google count All results are from php script directoy listings. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' It is written in PHP and uses a MySQL database server. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Many languages support this including PHP, bash scripts and perl. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Most web hosting providers support PHP for use by their clients. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' And it could happen if you use Microsoft Word 98 for Macintosh ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' First released for Lotus 1-2-3 and later also for Microsoft Excel. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' So really impressive Java programs will still require faster Internet connections. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' The Java computer language has been hailed as an Internet innovation. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Intel sees Java as a key building block, he said. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Schmidt said at an industry conference on Java in New York. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Sun Microsystems Inc . has a competitive programming language, Java. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' So a rogue Java program could seize control of the computer. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Java enables developers to embed mini-programs into Web pages. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Over 4 plus years of experience with Machine Learning using R language and Python. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Implementing client-server, web and desktop-based applications using C/C++ language. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Self- directed, detail-oriented, and professional C++ programmer ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Thorough knowledge of C/C++ programming concepts. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Knowledge of advanced level programming in C/C++ including thread synchronization multithreading ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Developed highly efficient algorithms in C++ through both pair-programming and independent work. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Specified, prototyped, developed and tested an object-oriented, multiplatform C++ framework. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Debugging and investigating issues utilizing C++ on the client server. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' C/C++ developer with experience in Object Oriented Analysis and Design ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Setting up and optimising Google Analytics properties and views in line with current product structure. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Strong knowledge of Google Analytics, as well as other analytics apps.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Building dashboards/customer segmentations, designing/analyzing digital marketing campaigns using Google Analytics ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Setting up and optimising Google Analytics properties and views in line with current product structure. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Hands-on experience with Google Analytics. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Proficient in configuring Google Analytics features. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Build infrastructure using Hadoop’s core components such as HBase, Kafka, and Hive ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Hands on experience with Running Pig and Hive Queries.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Analyzing data with Hive, Pig and HBase Data scrubbing and processing with Oozie. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Develop data solutions with Big Data technologies such as Hive. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Experience working in Hive or related tools on Hadoop. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Slide shows using Microsoft PowerPoint, displayed on a big screen in front. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' It is also supported by GIMP, Google Chrome, Microsoft PowerPoint and Microsoft Word. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Some applications commonly used with the Smart Board are Microsoft PowerPoint, Word, and AutoCAD. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' It is also used for the conversion of Microsoft PowerPoint presentations into elearning content. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Issue concerns use of Microsoft Powerpoint clip art. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Formats of files supported include Avi files, Microsoft Excel, Microsoft Powerpoint, Microsoft Word, Adobe PDF, MPEG-4 files. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' The software runs on Microsoft Access which operates only on Microsoft Windows. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' That is what Microsoft Access is designed for. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' The alliance gives Microsoft access to MCI's 20 million residential and business customers. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' In November, Microsoft released the first version of their popular database software Microsoft Access. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' The reporting engine is based on a portable Microsoft Access database. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' ASP . NET works really well with Microsoft SQL Server and Microsoft Access. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' It is written in PHP and uses a MySQL database server. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' I have a MySQL database table with about 2 million rows. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' MySQL database support is added as one such core component. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' MySQL Cluster is able to support cross-shard queries and transactions. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' It also supports REPLACE INTO as an alias for compatibility with MySQL.  ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' OpenSIS is written in PHP and uses MySQL to store information. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' And it could happen if you use Microsoft Word 98 for Macintosh ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' They wrote articles in Microsoft Word and gave the files to Souren. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Fortunately, it is possible to change the setting easily with Microsoft Word. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Then he pastes his work into Microsoft Word for revisions and corrections. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Microsoft Word 97 shows my name as the licensee in the opening window. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Fujitsu offers Microsoft Word, Excel and Office with some models of PC. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' If you have Microsoft Word on your computer, go to it. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' A complete and up-to-date index in Microsoft Excel format is available online. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' The main syntax for the formulation of rules adopts the Microsoft Excel format. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' It is a built-in feature of Microsoft Excel and Microsoft Access. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' If you are an accountant you are probably familiar with Microsoft Excel. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' First released for Lotus 1-2-3 and later also for Microsoft Excel. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Reports can be exported to Microsoft Excel or saved as Excel-compatible HTML files. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' My wife and I use Microsoft Outlook Express as our e-mail client. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' It was one of few readers that integrated directly with Microsoft Outlook. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' Almost immediately, my copy of Microsoft Outlook turned into Microsoft Look Out. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' It spreads primarily through Microsoft Outlook e-mail software on Windows computers. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' In Microsoft Outlook, time stamps are therefore stored and communicated without DST offsets. ', {'entities': [( -1 , 12 , 'soft_skills')]}
# ' America Online and Microsoft Outlook Express offer subscribers a similar function, Rampell said. ', {'entities': [( -1 , 12 , 'soft_skills')]}

# %%
# Fetching the NER component
ner = nlp.get_pipe("ner")
# Adding two more categories to NER component
for _, annotations in train:
  for ent in annotations.get("entities"):
    ner.add_label(ent[2])
# Disabling 'Tagger' and 'Parser'
disable_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
import random

# %%
from spacy.training.example import Example
from spacy.util import compounding
from spacy.util import minibatch

# Disabling 'Tagger' and 'Parser' components while training
with nlp.disable_pipes(*disable_pipes):
  optimizer = nlp.resume_training()

  for iteration in range(100):
    random.shuffle(train)
    losses = {}

    batches = minibatch(train, size=compounding(1.0, 4.0, 1.001))
    for batch in batches:
      examples = []
      for text, annotation in batch:
        example = Example.from_dict(nlp.make_doc(text), annotation)
        examples.append(example)

      nlp.update(
          examples,
          drop=0.5,
          losses=losses,
          sgd=optimizer
      )
    print("Losses: ", losses)
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Strong experience in JSON , HTML5 , Angular JS" with entities "[(28, 32, 'hard_skills')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Independently conducts rigorous statistical analys..." with entities "[(95, 105, 'hard_skills')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Communication with other countries was difficult d..." with entities "[(1, 14, 'soft_skills')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Knowledge of developing Rich interface application..." with entities "[(105, 108, 'hard_skills')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The apes are exhibiting previously unknown resourc..." with entities "[(56, 71, 'soft_skills')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Conduct data mining, data modeling, statistical an..." with entities "[(8, 19, 'hard_skills'), (20, 34, 'hard_skills'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Created visually impactful dashboards in Excel and..." with entities "[(41, 47, 'hard_skills'), (51, 58, 'hard_skills'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Advanced HTML5, CSS3 and JavaScript hard_skills ne..." with entities "[(16, 19, 'hard_skills')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Proficient in HTML5 Development" with entities "[(14, 18, 'hard_skills')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Web page layout hard_skills using HTML, CSS, XML/X..." with entities "[(35, 38, 'hard_skills')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses:  {'ner': 586.4512129065153}
# Losses:  {'ner': 405.40418507506797}
# Losses:  {'ner': 357.8080051607118}
# Losses:  {'ner': 279.4714073685196}
# Losses:  {'ner': 208.35211323280495}
# Losses:  {'ner': 218.24588095031092}
# Losses:  {'ner': 185.10091694147533}
# Losses:  {'ner': 176.1415614088908}
# Losses:  {'ner': 168.03808433559746}
# Losses:  {'ner': 129.55616835445772}
# Losses:  {'ner': 126.27346616965048}
# Losses:  {'ner': 122.48639778184128}
# Losses:  {'ner': 121.43609850017192}
# Losses:  {'ner': 92.33487947705318}
# Losses:  {'ner': 103.6401327958959}
# Losses:  {'ner': 101.65845762969245}
# Losses:  {'ner': 104.45249029333698}
# Losses:  {'ner': 98.79821401019771}
# Losses:  {'ner': 82.87163997319075}
# Losses:  {'ner': 67.25096190319537}
# Losses:  {'ner': 82.79867138163401}
# Losses:  {'ner': 77.42793419206761}
# Losses:  {'ner': 70.30831796970799}
# Losses:  {'ner': 86.97352521607327}
# Losses:  {'ner': 76.97484732182092}
# Losses:  {'ner': 82.72498121308546}
# Losses:  {'ner': 69.92260058922959}
# Losses:  {'ner': 63.334885324037955}
# Losses:  {'ner': 70.32767345668768}
# Losses:  {'ner': 68.12482057619837}
# Losses:  {'ner': 46.359072009920546}
# Losses:  {'ner': 49.54010273401599}
# Losses:  {'ner': 52.251807904697216}
# Losses:  {'ner': 48.251624019784394}
# Losses:  {'ner': 64.53939247346767}
# Losses:  {'ner': 42.04855942014524}
# Losses:  {'ner': 66.47112790416563}
# Losses:  {'ner': 55.94949801019899}
# Losses:  {'ner': 32.47005617303065}
# Losses:  {'ner': 42.120375950169304}
# Losses:  {'ner': 44.69375872286052}
# Losses:  {'ner': 65.23915767388021}
# Losses:  {'ner': 68.06727131999641}
# Losses:  {'ner': 42.79319505732699}
# Losses:  {'ner': 38.805013288048876}
# Losses:  {'ner': 59.53076953263681}
# Losses:  {'ner': 39.727392145617635}
# Losses:  {'ner': 33.088688401229874}
# Losses:  {'ner': 36.60639634545623}
# Losses:  {'ner': 41.62636087893818}
# Losses:  {'ner': 46.458388176807496}
# Losses:  {'ner': 32.37168769996144}
# Losses:  {'ner': 49.00575437973848}
# Losses:  {'ner': 37.252224469850034}
# Losses:  {'ner': 36.495131221946956}
# Losses:  {'ner': 32.37748112080244}
# Losses:  {'ner': 34.80472669150575}
# Losses:  {'ner': 51.495074410321195}
# Losses:  {'ner': 34.63733563285227}
# Losses:  {'ner': 30.70446825111032}
# Losses:  {'ner': 40.96883012417024}
# Losses:  {'ner': 49.32935615507443}
# Losses:  {'ner': 42.834092947806774}
# Losses:  {'ner': 43.75221787272968}
# Losses:  {'ner': 30.109222561066304}
# Losses:  {'ner': 44.76002803498962}
# Losses:  {'ner': 22.273077315845097}
# Losses:  {'ner': 29.474231706160115}
# Losses:  {'ner': 31.393084230118575}
# Losses:  {'ner': 21.60529564490676}
# Losses:  {'ner': 27.849315760483886}
# Losses:  {'ner': 28.192394245378626}
# Losses:  {'ner': 20.98627493679869}
# Losses:  {'ner': 26.44513640568524}
# Losses:  {'ner': 44.47155261210686}
# Losses:  {'ner': 32.55113199694962}
# Losses:  {'ner': 38.66332439120749}
# Losses:  {'ner': 18.060604703239974}
# Losses:  {'ner': 29.638823284562314}
# Losses:  {'ner': 16.724478470654237}
# Losses:  {'ner': 27.781177411591845}
# Losses:  {'ner': 34.26932773114727}
# Losses:  {'ner': 16.095143843205776}
# Losses:  {'ner': 27.53010030431629}
# Losses:  {'ner': 33.96748028012311}
# Losses:  {'ner': 25.88844683257126}
# Losses:  {'ner': 23.25981343923835}
# Losses:  {'ner': 27.16341522859643}
# Losses:  {'ner': 16.05813773608886}
# Losses:  {'ner': 24.91786959004793}
# Losses:  {'ner': 25.984601233462733}
# Losses:  {'ner': 32.15303222575309}
# Losses:  {'ner': 22.03603818564394}
# Losses:  {'ner': 25.706812534458557}
# Losses:  {'ner': 8.282488835232108}
# Losses:  {'ner': 36.63830561953121}
# Losses:  {'ner': 26.744096937402674}
# Losses:  {'ner': 33.06599760699449}
# Losses:  {'ner': 23.134557742870864}
# Losses:  {'ner': 29.98004395162543}
# Entities [('Microsoft Word', 'hard_skills'), ('SAS', 'hard_skills')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">They wrote articles in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft Word
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
#  and gave the files to Souren. Advanced SPSS, SQL and/or
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SAS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
#  programming skills including SQA BASE/STAT/MACRO/SQL.</div></span>

# %%
from spacy import displacy

# %%
nlp.to_disk('/content/nlp_model')

# %%
nlp_model = spacy.load(r'/content/nlp_model')

# %%
# !pip install PyMuPDF
# Out:
# Collecting PyMuPDF
#   Downloading PyMuPDF-1.23.5-cp310-none-manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 11.6 MB/s eta 0:00:00
# Collecting PyMuPDFb==1.23.5 (from PyMuPDF)
#   Downloading PyMuPDFb-1.23.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (30.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 15.1 MB/s eta 0:00:00
# Installing collected packages: PyMuPDFb, PyMuPDF
# Successfully installed PyMuPDF-1.23.5 PyMuPDFb-1.23.5

# %%
import fitz

fname = '/content/Pratyush Khare_IIITN_Data_Scientist.pdf'
doc = fitz.open(fname)
text = ""

for page in doc:
    text += page.get_text()

doc = nlp_model(text)
print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
displacy.render(doc, style="ent", jupyter=True)
# Out:
# Entities [('Computer Science', 'hard_skills'), ('C/C++', 'hard_skills'), ('Python', 'hard_skills'), ('Coursework', 'soft_skills'), ('Machine Learning', 'hard_skills'), ('NLP', 'hard_skills'), ('Data Structures', 'hard_skills'), ('algorithms', 'hard_skills'), ('Node.js', 'hard_skills'), ('MySQL', 'hard_skills'), ('Hindi', 'hard_skills'), ('KHARE', 'hard_skills'), ('Kota', 'hard_skills'), ('Kota', 'hard_skills'), ('machine learning', 'hard_skills'), ('PostgreSQL', 'hard_skills'), ('machine learning', 'hard_skills'), ('data analysis', 'hard_skills'), ('machine learning', 'hard_skills'), ('deep learning', 'hard_skills'), ('94.5', 'hard_skills'), ('ML', 'hard_skills'), ('Python', 'hard_skills'), ('NLP', 'hard_skills'), ('NER', 'hard_skills'), ('API', 'hard_skills'), ('GPT', 'hard_skills'), ('Machine Learning', 'hard_skills'), ('Python', 'hard_skills'), ('Deep Learning', 'hard_skills')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Bachelor of Technology in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Computer Science
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# <br>-<br>Indian Institute of Information Technology, Nagpur | <br> <br>CGPA - 8.43<br>Senior Secondary School<br>-<br>Bansal Public School Kota, RJ | <br> <br>Percent: 75.8%<br>High School Percentage<br>-<br>Bansal Public School Kota, RJ | <br> <br>Percent: 74%<br>SKILLS<br>Programming Languages:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C/C++
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
#  (Intermediate), HTML, CSS, JavaScript,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
#  (Intermediate).<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coursework
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">soft_skills</span>
# </mark>
# :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Machine Learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# , Object-oriented programming,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Data Structures
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     algorithms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# , Operating Systems, Computer <br>Networks, DBMS, Software Engineering<br>Libraries/Frameworks:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Node.js
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# <br>Tools / Platforms: Linux, GitHub<br>Databases:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MySQL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# <br>Spoken Language: English,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hindi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# <br>Epileptic Seizure Classification<br>-<br>LINK: http://43.204.253.145/<br>Credit Card Fraud Detection<br>-<br>LINK: https://github.com/Pratyushk2003/GITHUB-Analysis-Mercor<br>Resume Parser<br>-<br>LINK: https://github.com/Pratyushk2003/Resume-parsing<br>GitHub Automated Analysis Project<br>-<br>LINK: https://github.com/Pratyushk2003/GITHUB-Analysis-Mercor<br>PRATYUSH
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     KHARE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# <br>+919660784378<br>pratyushk824.786@gmail.com<br>Nagpur, India<br>Linkedin<br>Github<br>Leetcode<br>EDUCATION<br>Dec '20<br>Jul '24<br>Nagpur, MH<br>Mar '19<br>May '20<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kota
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# , RJ<br>Mar '17<br>May '18<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kota
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# , RJ<br>PROJECTS<br>Jun '23<br>Present<br>Developed a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     machine learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# -driven solution to predict epileptic seizures, catering to challenging, visually undetectable cases.<br>•<br>Used binary classification models to create a responsive and impactful healthcare tool.<br>•<br>Successfully deployed a user-friendly interface for early seizure detection.<br>•<br>Employed a range of technologies, including Python, Flask,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PostgreSQL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# , and various libraries, to develop the solution.<br>•<br>Demonstrated expertise in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     machine learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     data analysis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# , and system deployment<br>•<br>Contributed to the improvement of epilepsy management through a project<br>•<br>Apr '23<br>Apr '23<br>Developed an automated and accurate system to detect credit card fraud using
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     machine learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
#  models and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     deep learning
#     <spa

# %%
import fitz
import spacy
from spacy import displacy
from spacy.util import minibatch
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

# Load the resume and job description PDFs
resume_file = '/content/Pratyush Khare_IIITN_Data_Scientist.pdf'
job_description_file = '/content/Backend - Software Engineer (Intern).docx.pdf'

# Function to extract entities and return them as a list
def extract_entities(text):
    doc = nlp_model(text)
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    return entities

# Extract entities from the resume and job description
resume_text = ""
job_description_text = ""

# Extract text from the resume PDF
resume_doc = fitz.open(resume_file)
for page in resume_doc:
    resume_text += page.get_text()

# Extract text from the job description PDF
job_description_doc = fitz.open(job_description_file)
for page in job_description_doc:
    job_description_text += page.get_text()

# Extract entities from the resume and job description
resume_entities = extract_entities(resume_text)
job_description_entities = extract_entities(job_description_text)

# Print the entities from the resume and job description
print("Entities in Resume:", resume_entities)
print("Entities in Job Description:", job_description_entities)

# Calculate cosine similarity between the two sets of entities
def calculate_cosine_similarity(entity_set1, entity_set2):
    all_entities = list(entity_set1.union(entity_set2))
    vector_set1 = [1 if entity in entity_set1 else 0 for entity in all_entities]
    vector_set2 = [1 if entity in entity_set2 else 0 for entity in all_entities]

    similarity = cosine_similarity([vector_set1], [vector_set2])[0][0]
    return similarity

resume_entities_set = set(entity[0] for entity in resume_entities)
job_description_entities_set = set(entity[0] for entity in job_description_entities)

cosine_similarity_score = calculate_cosine_similarity(resume_entities_set, job_description_entities_set)
print("Cosine Similarity between Resume and Job Description Entities:", cosine_similarity_score)

# Visualize the entities in the resume
print("\n\nResume Text\n")
displacy.render(nlp_model(resume_text), style="ent", jupyter=True)

print("\n\nJob Description\n")
displacy.render(nlp_model(job_description_text), style="ent", jupyter=True)
# Out:
# Entities in Resume: [('Computer Science', 'hard_skills'), ('C/C++', 'hard_skills'), ('Python', 'hard_skills'), ('Coursework', 'soft_skills'), ('Machine Learning', 'hard_skills'), ('NLP', 'hard_skills'), ('Data Structures', 'hard_skills'), ('algorithms', 'hard_skills'), ('Node.js', 'hard_skills'), ('MySQL', 'hard_skills'), ('Hindi', 'hard_skills'), ('KHARE', 'hard_skills'), ('Kota', 'hard_skills'), ('Kota', 'hard_skills'), ('machine learning', 'hard_skills'), ('PostgreSQL', 'hard_skills'), ('machine learning', 'hard_skills'), ('data analysis', 'hard_skills'), ('machine learning', 'hard_skills'), ('deep learning', 'hard_skills'), ('94.5', 'hard_skills'), ('ML', 'hard_skills'), ('Python', 'hard_skills'), ('NLP', 'hard_skills'), ('NER', 'hard_skills'), ('API', 'hard_skills'), ('GPT', 'hard_skills'), ('Machine Learning', 'hard_skills'), ('Python', 'hard_skills'), ('Deep Learning', 'hard_skills')]
# Entities in Job Description: [('HTML', 'hard_skills'), ('DBMS', 'hard_skills'), ('SQL', 'hard_skills'), ('NoSQL', 'hard_skills'), ('REST', 'hard_skills'), ('Data Structures', 'hard_skills'), ('Algorithms', 'hard_skills'), ('time complexity', 'soft_skills'), ('complexity', 'soft_skills'), ('communication', 'soft_skills'), ('problem-solving', 'soft_skills'), ('fast-paced', 'soft_skills')]
# Cosine Similarity between Resume and Job Description Entities: 0.06019292654288461
#
#
# Resume Text
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Bachelor of Technology in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Computer Science
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# <br>-<br>Indian Institute of Information Technology, Nagpur | <br> <br>CGPA - 8.43<br>Senior Secondary School<br>-<br>Bansal Public School Kota, RJ | <br> <br>Percent: 75.8%<br>High School Percentage<br>-<br>Bansal Public School Kota, RJ | <br> <br>Percent: 74%<br>SKILLS<br>Programming Languages:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C/C++
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
#  (Intermediate), HTML, CSS, JavaScript,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
#  (Intermediate).<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coursework
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">soft_skills</span>
# </mark>
# :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Machine Learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# , Object-oriented programming,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Data Structures
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     algorithms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# , Operating Systems, Computer <br>Networks, DBMS, Software Engineering<br>Libraries/Frameworks:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Node.js
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# <br>Tools / Platforms: Linux, GitHub<br>Databases:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MySQL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# <br>Spoken Language: English,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hindi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# <br>Epileptic Seizure Classification<br>-<br>LINK: http://43.204.253.145/<br>Credit Card Fraud Detection<br>-<br>LINK: https://github.com/Pratyushk2003/GITHUB-Analysis-Mercor<br>Resume Parser<br>-<br>LINK: https://github.com/Pratyushk2003/Resume-parsing<br>GitHub Automated Analysis Project<br>-<br>LINK: https://github.com/Pratyushk2003/GITHUB-Analysis-Mercor<br>PRATYUSH
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     KHARE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# <br>+919660784378<br>pratyushk824.786@gmail.com<br>Nagpur, India<br>Linkedin<br>Github<br>Leetcode<br>EDUCATION<br>Dec '20<br>Jul '24<br>Nagpur, MH<br>Mar '19<br>May '20<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kota
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# , RJ<br>Mar '17<br>May '18<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kota
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# , RJ<br>PROJECTS<br>Jun '23<br>Present<br>Developed a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     machine learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# -driven solution to predict epileptic seizures, catering to challenging, visually undetectable cases.<br>•<br>Used binary classification models to create a responsive and impactful healthcare tool.<br>•<br>Successfully deployed a user-friendly interface for early seizure detection.<br>•<br>Employed a range of technologies, including Python, Flask,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PostgreSQL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# , and various libraries, to develop the solution.<br>•<br>Demonstrated expertise in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     machine learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     data analysis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# , and system deployment<br>•<br>Contributed to the improvement of epilepsy management through a project<br>•<br>Apr '23<br>Apr '23<br>Developed an automated and accurate system to detect credit card fraud using
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     machine learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
#  models and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     deep learning
#     <spa
# Job Description
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Backend - Software Engineer (Intern)<br>We at Buyhatke aim to give the ultimate user experience on any transactions online; be it online<br>shopping, flight or train ticket booking, purchases or even crypto transactions. As we grow, we<br>continue to expand our portfolio of products and services with new offerings like Buyhatke, Bitbns,<br>Salesla, UseMyCards, TatkalForSure and more.<br>Bitbns is India’s most liquid crypto exchange. With over 4.8 million users bitbns has seen rapid<br>growth over time. Bitbns has built global first products around web3. Launchonascent.com<br>bitdroplet.com/dapp to name a few. We are working on building some ambitious web3 products<br>and would love for folks keen to join us.<br>Responsibilities:<br>✔ Conceptualize, Design, Build, Test and Maintain applications powering the APIs used by<br>BITBNS users.<br>✔ Managing User Activity logs - Trade, Movement of Funds and subscription to different<br>Investment plans.<br>✔ Derive meaningful analytics from the logs - Both for the users and business development<br>teams to drive customer acquisition and retention.<br>✔ Automation of User reports - Detailed summary, Aggregate summary of user activity.<br>✔ Generating meaningful Profit &amp; Loss Statistics for the users and showcase the same in user<br>accounts.<br>✔ Design and build applications to meet our ever-increasing data generation.<br>✔ Testing new solutions to power the same to reduce latency while minimizing cost.<br>Requirements:<br>✔ Knowledge of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HTML
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# , CSS, JavaScript and its libraries (NodeJS, ReactJS)<br>✔ Knowledge of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DBMS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
#  concepts,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SQL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NoSQL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
#  databases<br>✔ Knowledge of software development life cycle, development models etc<br>✔ Knowledge of Object-Oriented Programming Concepts<br>✔ Knowledge of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     REST
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
#  APIs<br>✔ Knowledge of using Version Control systems like git.<br>✔ Knowledge of different methods of API authentications.<br>✔ Knowledge of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Data Structures
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
#  &amp;
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Algorithms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">hard_skills</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     time complexity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">soft_skills</span>
# </mark>
# , space
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     complexity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">soft_skills</span>
# </mark>
# , asymptotic<br>notations<br>Brownie Points:<br>✔ Experience with various programming languages<br>✔ Strong
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     communication
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">soft_skills</span>
# </mark>
#  and presentation skills<br>✔ Self-motivated and results-oriented<br>✔ Ability to interact with cross-functional teams<br>✔ Strong
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     problem-solving
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">soft_skills</span>
# </mark>
#  abilities<br>✔ Highly developed analytical and organizational skills<br>✔ Ability to work in a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fast-paced
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">soft_skills</span>
# </mark>
#  environment<br></div></span>

# %%
# !pip install langdetect
# !pip install translate
# Out:
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 9.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect) (1.16.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993224 sha256=3cfc0166282f7ec9bad08a696015d91a13fcab2957608f1cdbfb44c70cf98f93
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9
# Collecting translate
#   Downloading translate-3.6.1-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from translate) (8.1.7)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from translate) (4.9.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from translate) (2.31.0)
# Collecting libretranslatepy==2.1.1 (from translate)
#   Downloading libretranslatepy-2.1.1-py3-none-any.whl (3.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->translate) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->translate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->translate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->translate) (2023.7.22)
# Installing collected packages: libretranslatepy, translate
# Successfully installed libretranslatepy-2.1.1 translate-3.6.1

# %%
from translate import Translator

# %%
from translate import Translator
import fitz

job_description_file = '/content/バックエンド.pdf'
job_description_text = ""
job_description_doc = fitz.open(job_description_file)
for page in job_description_doc:
    job_description_text += page.get_text()

translator = Translator(to_lang="en", from_lang="ja")
translated_text = ""
chunk_size = 500
for i in range(0, len(job_description_text), chunk_size):
    chunk = job_description_text[i:i + chunk_size]
    translated_chunk = translator.translate(chunk)
    translated_text += translated_chunk

print("Translated Text (English):")
print(translated_text)
# Out:
# Translated Text (English):
# Backend - Software Engineer (IN
# turn)
# We Buyhatke in online trading
# Provide the ultimate user experience.
# and.whether you're online,
# Pre-sale of shopping, flights and train tickets
# About, purchase, and even trade cryptocurrencies.As we grow,
#
# Buyhatke, Bitbns, Salesla,
# UseMyCards, TatkalForSure, and more.
# Bitbns is India's most liquid cryptocurrency
# It is a reference point. Has over 4.8 million users
# bitbns is growing rapidly
# It grows over time. Bitbns
# built the world's first product around web3.
# Launchonascent.com
# To name a few, bitdroplet.com/dapp.
# We are building some ambitious Web3 products
# We are working on
# Welcome people who want to join us
# Yes,
# I am responsible for:
# Applications that leverage the APIs✔ used
# conceptualize, design, build, tess(g) Maintenance
# BITBNS users.
# ✔ Manage User Activity Logs - Transactions,
# Moving funds, subscribing to different services
# Reimbursement
# Investment Plan.
# Derive meaningful analytics from✔ logs - users
# for both and business development
# Your team drives customer acquisition and retention.
# ✔ User Report Automation - Detailed Overview
# Summary summary of the aggregation of the laser activity.
# Generate P&L statistics that are meaningful to the✔ user
# and show it to the user
# Account.
# Applications for✔ Growing Data Generation
# Design and build your shots.
# Reduce latency while minimizing✔ costs
# to power new solutions
# to test new solutions for
# Yes.
# Requirements:
# ✔ HTML, CSS, JavaScript and their libraries
# Knowledge of (NodeJS, ReactJS)
# ✔ DBMS concepts, SQL and NoSQL data bays
# Knowledge of Su
# ✔ Software development lifecycle, development model
# Knowledge such as le
# Knowledge related to the concept of✔ object-oriented programmingKnowledge
# of✔ rest APIs
# concerning the use of version control systems such as✔ git
# Knowledge.
# Knowledge of the different methods of✔ API authentication.
# ✔ Data Structures and Algorithms, Time Computation, Empty
# Knowledge of intercomputation and asymptotic computation
# Conventions
# Brownie Points:
# Experience with✔ different programming languages
# ✔ Excellent communication skills and presentations
# Potion Ability
# ✔ Spontaneous and results-oriented
# Ability to interact with✔ cross-functional teams
# ✔ Excellent problem-solving skills
# ✔ Highly developed analytical and organizational skills
# ✔ Ability to work in a fast-paced environment

# %%
import fitz
import spacy
from sklearn.metrics.pairwise import cosine_similarity
from langdetect import detect
from translate import Translator

# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

# Function to extract entities and return them as a list
def extract_entities(text):
    doc = nlp_model(text)
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    return entities

# Define PDF file paths
resume_file = '/content/Pratyush Khare_IIITN_Data_Scientist.pdf'
job_description_file = '/content/バックエンド.pdf'

# Extract text from the resume and job description PDFs
resume_text = ""
job_description_text = ""

# Extract text from the resume PDF
resume_doc = fitz.open(resume_file)
for page in resume_doc:
    resume_text += page.get_text()

# Extract text from the job description PDF
job_description_doc = fitz.open(job_description_file)
for page in job_description_doc:
    job_description_text += page.get_text()

# Detect the language of the documents and translate to English if needed
def translate_to_english(text):
    if detect(text) != 'en':
        translator = Translator(to_lang='en', from_lang=detect(text))
        translated_text = ""
        chunk_size = 500  # Adjust the chunk size as needed
        text_chunks = [text[i:i + chunk_size] for i in range(0, len(text), chunk_size)]
        for chunk in text_chunks:
            translated_chunk = translator.translate(chunk)
            translated_text += translated_chunk
        return translated_text
    else:
        return text

resume_text = translate_to_english(resume_text)
job_description_text = translate_to_english(job_description_text)

# Extract entities from the resume and job description
resume_entities = extract_entities(resume_text)
job_description_entities = extract_entities(job_description_text)

# Print the entities from the resume and job description
print("Entities in Resume:", resume_entities)
print("Entities in Job Description:", job_description_entities)

# Calculate cosine similarity between the two sets of entities
def calculate_cosine_similarity(entity_set1, entity_set2):
    all_entities = list(entity_set1.union(entity_set2))
    vector_set1 = [1 if entity in entity_set1 else 0 for entity in all_entities]
    vector_set2 = [1 if entity in entity_set2 else 0 for entity in all_entities]
    similarity = cosine_similarity([vector_set1], [vector_set2])[0][0]
    return similarity

resume_entities_set = set(entity[0] for entity in resume_entities)
job_description_entities_set = set(entity[0] for entity in job_description_entities)

cosine_similarity_score = calculate_cosine_similarity(resume_entities_set, job_description_entities_set)
print("Cosine Similarity between Resume and Job Description Entities:", cosine_similarity_score)


# Visualize the entities in the resume
print("\n\nResume Text\n")
displacy.render(nlp_model(resume_text), style="ent", jupyter=True)

print("\n\nJob Description\n")
displacy.render(nlp_model(job_description_text), style="ent", jupyter=True)
# Out:
# Entities in Resume: [('Bachelor of Technology', 'ORG'), ('Indian Institute of Information Technology', 'ORG'), ('Nagpur', 'ORG'), ('8.43', 'CARDINAL'), ('Secondary School', 'ORG'), ('75.8%', 'PERCENT'), ('74%', 'PERCENT'), ('CSS', 'ORG'), ('JavaScript', 'ORG'), ('NLP', 'ORG'), ('Data Structures', 'ORG'), ('Operating Systems', 'ORG'), ('Computer \nNetworks', 'ORG'), ('DBMS', 'ORG'), ('Software Engineering\nLibraries/Frameworks', 'ORG'), ('Tools / Platforms', 'ORG'), ('Linux', 'PERSON'), ('GitHub', 'ORG'), ('Spoken Language:', 'WORK_OF_ART'), ('English', 'LANGUAGE'), ('Hindi\nEpileptic Seizure Classification', 'ORG'), ('http://43.204.253.145/\nCredit Card Fraud Detection', 'PERSON'), ('Resume Parser', 'PERSON'), ('GitHub Automated Analysis Project', 'ORG'), ('KHARE', 'ORG'), ('Nagpur', 'GPE'), ('India', 'GPE'), ('Linkedin', 'GPE'), ('24', 'CARDINAL'), ('Nagpur', 'ORG'), ('MH', 'ORG'), ("May '20", 'DATE'), ('Kota', 'PERSON'), ("May '18", 'DATE'), ('Kota', 'PERSON'), ('•\nSuccessfully', 'PRODUCT'), ('•\nEmployed', 'PRODUCT'), ('Python', 'GPE'), ('Flask', 'GPE'), ("•\nApr '", 'PRODUCT'), ('23', 'CARDINAL'), ('94.5%', 'PERCENT'), ('8%', 'PERCENT'), ('ML', 'ORG'), ("•\nJun '", 'PRODUCT'), ('Python', 'ORG'), ('NLP', 'ORG'), ('•\nUtilized', 'PRODUCT'), ('Named Entity Recognition', 'WORK_OF_ART'), ('NER', 'ORG'), ('•\nDesigned', 'PRODUCT'), ("•\nJun '", 'PRODUCT'), ('23', 'CARDINAL'), ('GitHub', 'ORG'), ('•\n• Automated', 'PRODUCT'), ('GitHub API', 'ORG'), ('GPT', 'ORG'), ('the Machine Learning Project', 'ORG'), ('Mercor', 'ORG'), ('Digital Transformation', 'ORG'), ('Basic Programming using Python', 'WORK_OF_ART'), ('Build', 'GPE'), ('first', 'ORDINAL'), ('AI Stock Predictor', 'ORG'), ('Amazon', 'ORG'), ('Coursera\nhttps://www.coursera.org/account/accomplishments/verify/NSFNS4FBMRF8\nFundamentals of Deep Learning - NVIDIA', 'PERSON'), ('Leetcode Contest Rating', 'PERSON'), ('1501', 'DATE'), ('Leetcode', 'GPE'), ('1501', 'DATE'), ('•\nLinks', 'PRODUCT'), ('•\nhttps://www.cloudskillsboost.google/public_profiles/928dd08c-618a41ff-bbcc-0c500b13396b\n○\nhttps://www.cloudskillsboost.google/public_profiles/b2f5da93-89e4-4ced-83d8-6cdab3f6238e', 'PRODUCT'), ("'22", 'DATE'), ("May '21\nJan '22", 'DATE'), ('Sep', 'ORG')]
# Entities in Job Description: [('Backend - Software Engineer', 'ORG'), ('Salesla', 'ORG'), ('Bitbns', 'PERSON'), ('India', 'GPE'), ('over 4.8 million', 'CARDINAL'), ('first', 'ORDINAL'), ('web3', 'LOC'), ('Launchonascent.com', 'ORG'), ('BITBNS', 'ORG'), ('User Report Automation - Detailed Overview\nSummary', 'WORK_OF_ART'), ('Generate P&L', 'PERSON'), ('Growing Data Generation\nDesign', 'WORK_OF_ART'), ('Reduce', 'PERSON'), ('CSS', 'ORG'), ('JavaScript', 'ORG'), ('DBMS', 'ORG'), ('SQL', 'ORG'), ('NoSQL', 'ORG'), ('Knowledge of Su \n✔ Software development lifecycle', 'WORK_OF_ART'), ('API', 'ORG'), ('Data Structures', 'ORG'), ('Algorithms', 'PERSON'), ('Brownie Points', 'ORG')]
# Cosine Similarity between Resume and Job Description Entities: 0.1539981007018036
#
#
# Resume Text
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bachelor of Technology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in Computer Science<br>-<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indian Institute of Information Technology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nagpur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  | <br> <br>CGPA -
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8.43
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# <br>Senior
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Secondary School
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br>-<br>Bansal Public School Kota, RJ | <br> <br>Percent:
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     75.8%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# <br>High School Percentage<br>-<br>Bansal Public School Kota, RJ | <br> <br>Percent:
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     74%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# <br>SKILLS<br>Programming Languages: C/C++ (Intermediate), HTML,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CSS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JavaScript
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Python (Intermediate).<br>Coursework: Machine Learning,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Object-oriented programming,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Data Structures
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and algorithms,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Operating Systems
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Computer
# Networks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DBMS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Software Engineering
# Libraries/Frameworks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# : Node.js<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tools / Platforms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# :
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Linux
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GitHub
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br>Databases: MySQL<br>
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spoken Language:
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     English
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LANGUAGE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hindi
# Epileptic Seizure Classification
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br>-<br>LINK:
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     http://43.204.253.145/
# Credit Card Fraud Detection
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>-<br>LINK: https://github.com/Pratyushk2003/GITHUB-Analysis-Mercor<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Resume Parser
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>-<br>LINK: https://github.com/Pratyushk2003/Resume-parsing<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GitHub Automated Analysis Proje
# Job Description
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Backend - Software Engineer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (IN<br>turn) <br>We Buyhatke in online trading<br>Provide the ultimate user experience.<br>and.whether you're online, <br>Pre-sale of shopping, flights and train tickets<br>About, purchase, and even trade cryptocurrencies.As we grow,<br> <br>Buyhatke, Bitbns,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Salesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,<br>UseMyCards, TatkalForSure, and more. <br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitbns
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's most liquid cryptocurrency<br>It is a reference point. Has
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     over 4.8 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  users <br>bitbns is growing rapidly <br>It grows over time. Bitbns <br>built the world's
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  product around
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     web3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . <br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Launchonascent.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  <br>To name a few, bitdroplet.com/dapp.<br>We are building some ambitious Web3 products<br>We are working on <br>Welcome people who want to join us<br>Yes,<br>I am responsible for: <br>Applications that leverage the APIs✔ used<br>conceptualize, design, build, tess(g) Maintenance <br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BITBNS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  users. <br>✔ Manage User Activity Logs - Transactions,<br>Moving funds, subscribing to different services<br>Reimbursement <br>Investment Plan. <br>Derive meaningful analytics from✔ logs - users<br>for both and business development <br>Your team drives customer acquisition and retention. <br>✔
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     User Report Automation - Detailed Overview
# Summary
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  summary of the aggregation of the laser activity. <br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Generate P&amp;L
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  statistics that are meaningful to the✔ user<br>and show it to the user <br>Account. <br>Applications for✔
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Growing Data Generation
# Design
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  and build your shots. <br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reduce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  latency while minimizing✔ costs<br>to power new solutions<br>to test new solutions for<br>Yes. <br>Requirements: <br>✔ HTML,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CSS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JavaScript
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and their libraries <br>Knowledge of (NodeJS, ReactJS) <br>✔
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DBMS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  concepts,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SQL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NoSQL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  data bays<br>
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Knowledge of Su
# ✔ Software development lifecycle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# , development model<br>Knowledge such as le <br>Knowledge related to the concept of✔ object-oriented programmingKnowledge <br>of✔ rest APIs <br>concerning the use of version control systems such as✔ git<br>Knowledge. <br>Knowledge of the different methods of✔
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     API
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5re
